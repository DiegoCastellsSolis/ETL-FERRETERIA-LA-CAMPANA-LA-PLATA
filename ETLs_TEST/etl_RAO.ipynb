# %%
import os
import pandas as pd
import re

# %%
directorio = './data/raw'  # Reemplaza esto con la ruta de tu directorio

# Verifica si el directorio existe 
if os.path.exists(directorio) and os.path.isdir(directorio): 
    archivos = os.listdir(directorio)
    if archivos:
        print("Archivos en el directorio:") 
        for archivo in archivos[:1]: 
            print(archivo) 
            path = directorio+'/'+archivo
            df = pd.read_excel(path,header=9, usecols="B:F") 
    else:
        print("El directorio está vacío.") 
else: 
    print("El directorio no existe o no es válido.")
# Out:
# Archivos en el directorio:
# RAO.xlsx

# %% [markdown]
# OBTENGO LOS NOMBRES DE LOS ELEMENTOS

# %%
dfx = df
dfx = dfx.rename(columns={
    'Unnamed: 1': 'codigo',
    'Unnamed: 2': 'descripcion',
    'Unnamed: 3': 'empaque',
    'Unnamed: 4': 'raw',
    'Unnamed: 5': 'precio'
}) 
dfx = dfx.dropna(subset=['codigo'])  

# Restablecer los índices del DataFrame
dfx.reset_index(drop=True, inplace=True) 

list_articles = [item for item in df[df.columns[0]].tolist() if item != "Código" and not pd.isna(item) and not re.match(r'\d+\.\d+', str(item)) and "Plástico" not in item and "Poliestireno" not in item ]

# %%
len(list_articles)
print(list_articles)
# Out:
# ['FLOTANTES ACCIONAMIENTO HORIZONTAL', 'FLOTANTES ALTA PRESION - SIN BOYA', 'CONJUNTOS DE REPARACION', 'BOYAS PARA TANQUE DE AGUA', 'Polietileno Alta Densidad', 'BOYAS PARA DEPOSITO DE AGUA', 'ACERO INOXIDABLE', 'CHAPA C/PINTURA ANTIOXIDO (aptas para pintar)', 'TUBOBLEX ROSCA NORMAL 1/2"', 'TUBOBLEX ROSCA NORMAL 3/4"', 'TUBOFLEX ROSCA LARGA - Incluye roseta', 'TUBOFLEX PASO TOTAL', 'MODELO CORTO', 'MODELO LARGO', 'CONJUNTOS (incluye 1 corto + 1 largo)', 'FLEXINOX 1/2" MACHO GIRATORIO', 'FLEXINOX 3/4" MACHO FIJO', 'FLEXIBLES EXTENSIBLES PARA GAS', 'REPUESTOS P/ SIFONES DE PVC', 'SOPAPAS P/PILETA DE COCINA', 'SOPAPAS P/LAVATORIO', 'SOPAPAS P/BAÑERA', 'REPUESTOS PARA SOPAPAS']

# %%
dfx
# Out:
#                                  codigo  \
# 0    FLOTANTES ACCIONAMIENTO HORIZONTAL
# 1                                Código
# 2                             13000.649
# 3                             13000.650
# 4     FLOTANTES ALTA PRESION - SIN BOYA
# ..                                  ...
# 238                  9900.113
# 239                            9900.661
# 240                  9900.117
# 241                            9900.662
# 242                            9900.666
#
#                                            descripcion  empaque  raw  \
# 0                                                  NaN      NaN  NaN
# 1                                     Descripción       Empaque  NaN
# 2                               FLOTANTE COMPLETO 1/2"       24  NaN
# 3                               FLOTANTE COMPLETO 3/4"       12  NaN
# 4                                                  NaN      NaN  NaN
# ..                                                 ...      ...  ...
# 238         TORNILLO P/SOPAPA LAVATORIO 3/16 x 3"            20  NaN
# 239            TORNILLO P/SOPAPA COCINA 3/16 x 2"            20  NaN
# 240            REJILLA ACERO INOX.  P/SOPAPA LAVATORIO       20  NaN
# 241               REJILLA ACERO INOX.  P/SOPAPA COCINA       20  NaN
# 242  REJILLA ACERO INOX.  C/TORNILLO CROMADO P/SOPA...       20  NaN
#
#           precio
# 0            NaN
# 1            NaN
# 2    3867.054857
# 3    4114.963256
# 4            NaN
# ..           ...
# 238   189.138146
# 239   189.138146
# 240   373.301869
# 241   373.301869
# 242   373.301869
#
# [243 rows x 5 columns]

# %%
# Renombrar las columnas
df = df.rename(columns={
    'Unnamed: 1': 'codigo',
    'Unnamed: 2': 'descripcion',
    'Unnamed: 3': 'empaque',
    'Unnamed: 4': 'raw',
    'Unnamed: 5': 'precio'
})
#ELIMINO LA COLUMNA 3 QUE AL EXISTIR UN COLUMNA DIVISORIA ENTRE DESCRIPCION Y PRECIO POSEE VALORES BASURA
df = df.drop('raw', axis=1)
df = df.dropna(subset=['codigo'])

# %%
# Crear la nueva columna 'tipo_product'
df['producto'] = None
current_tipo_product = None

# Definir las palabras a excluir
palabras_excluir = ["Plástico", "Poliestireno"]

# Filtrar la columna 'codigo' para excluir las palabras
for palabra in palabras_excluir:
    df = df[~df['codigo'].str.contains(palabra, case=False)]

# Restablecer el índice del DataFrame
df.reset_index(drop=True, inplace=True)

for index, row in df.iterrows():
    codigo = row['codigo']
    if codigo in list_articles:
        current_tipo_product = codigo
    df.at[index, 'producto'] = current_tipo_product
    
df = df.dropna(subset=['precio'])

# %%
df.head(30)
# Out:
#                 codigo                                        descripcion  \
# 2            13000.649                             FLOTANTE COMPLETO 1/2"
# 3            13000.650                             FLOTANTE COMPLETO 3/4"
# 6            13001.805                         FLOTANTE ALTA PRESION 1/2"
# 7            13001.806       FLOTANTE ALTA PRESION 1/2" VARILLA REGULABLE
# 8            13001.807                         FLOTANTE ALTA PRESION 3/4"
# 9            13001.808       FLOTANTE ALTA PRESION 3/4" VARILLA REGULABLE
# 10           13001.809                           FLOTANTE ALTA PRESION 1"
# 12           13000.724                             FLOTANTE COMPLETO 1/2"
# 15           13000.657  CONJUNTO REPARACION 1/2"  ( EMBOLO + TORNILLO ...
# 16           13000.658  CONJUNTO REPARACION 3/4"  ( EMBOLO + TORNILLO ...
# 20           13000.659                                     BOYA ROJA 1/2"
# 21           13000.660                                     BOYA ROJA 3/4"
# 23           13000.706                           BOYA P/TANQUE COMUN 1/2"
# 24           13000.707                          BOYA  P/TANQUE COMUN 3/4"
# 25           13000.708                             BOYA P/TANQUE COMUN 1"
# 26           13000.709                    BOYA P/TANQUE DE PRESION 1/2"
# 27           13000.710                      BOYA P/TANQUE DE PRESION 3/4"
# 28           13000.711                       BOYA P/TANQUE  DE PRESION 1"
# 29           13000.712                    BOYA P/TANQUE DE PRESION 1 1/4"
# 30           13000.713                    BOYA P/TANQUE DE PRESION 1 1/2"
# 31           13000.714                        BOYA P/TANQUE DE PRESION 2"
# 34           13000.715                           BOYA P/DEPOSITO 2 ROSCAS
# 35           13000.716                      BOYA P/DEPOSITO TIPO "FERRUM"
# 36           13000.717                     BOYA P/DEPOSITO TIPO "CAPEA"
# 38           13000.718                    BOYA P/ DEPOSITO PLASTICA CHATA
# 39           13000.719              BOYA P/ DEPOSITO PLASTICA EXTRA CHATA
# 42  10000.610                                          TAPA 15 cm x 15 cm
# 43  10001.611                                          TAPA 15 cm x 20 cm
# 44  10002.612                                          TAPA 20 cm x 20 cm
# 45  10003.613                                          TAPA 20 cm x 25 cm
#
#    empaque        precio                            producto
# 2       24   3867.054857  FLOTANTES ACCIONAMIENTO HORIZONTAL
# 3       12   4114.963256  FLOTANTES ACCIONAMIENTO HORIZONTAL
# 6       10   5972.612938   FLOTANTES ALTA PRESION - SIN BOYA
# 7       10   6485.983497   FLOTANTES ALTA PRESION - SIN BOYA
# 8       10   7370.008542   FLOTANTES ALTA PRESION - SIN BOYA
# 9       10   7943.066066   FLOTANTES ALTA PRESION - SIN BOYA
# 10      10  10984.124751   FLOTANTES ALTA PRESION - SIN BOYA
# 12      40   1450.452459   FLOTANTES ALTA PRESION - SIN BOYA
# 15      10    682.899969             CONJUNTOS DE REPARACION
# 16      10    749.299840             CONJUNTOS DE REPARACION
# 20      10    758.750469           Polietileno Alta Densidad
# 21      10    929.455824           Polietileno Alta Densidad
# 23      10    387.429474           Polietileno Alta Densidad
# 24      10    414.280670           Polietileno Alta Densidad
# 25      10    506.750468           Polietileno Alta Densidad
# 26      10   1039.643432           Polietileno Alta Densidad
# 27      10   1232.686053           Polietileno Alta Densidad
# 28      10   1300.608456           Polietileno Alta Densidad
# 29      10   4748.127229           Polietileno Alta Densidad
# 30      10   7030.081667           Polietileno Alta Densidad
# 31       6   7924.909684           Polietileno Alta Densidad
# 34      10    373.527228         BOYAS PARA DEPOSITO DE AGUA
# 35      10    395.532498         BOYAS PARA DEPOSITO DE AGUA
# 36      10    478.469327         BOYAS PARA DEPOSITO DE AGUA
# 38      10    492.823407         BOYAS PARA DEPOSITO DE AGUA
# 39      10    492.823407         BOYAS PARA DEPOSITO DE AGUA
# 42       4   4448.556300                    ACERO INOXIDABLE
# 43       4   5049.708785                    ACERO INOXIDABLE
# 44       4   5933.432248                    ACERO INOXIDABLE
# 45       4   6752.183229                    ACERO INOXIDABLE

# %%
df
# Out:
#                  codigo                                        descripcion  \
# 2             13000.649                             FLOTANTE COMPLETO 1/2"
# 3             13000.650                             FLOTANTE COMPLETO 3/4"
# 6             13001.805                         FLOTANTE ALTA PRESION 1/2"
# 7             13001.806       FLOTANTE ALTA PRESION 1/2" VARILLA REGULABLE
# 8             13001.807                         FLOTANTE ALTA PRESION 3/4"
# ..                  ...                                                ...
# 235  9900.113                   TORNILLO P/SOPAPA LAVATORIO 3/16 x 3"
# 236            9900.661            TORNILLO P/SOPAPA COCINA 3/16 x 2"
# 237  9900.117                      REJILLA ACERO INOX.  P/SOPAPA LAVATORIO
# 238            9900.662               REJILLA ACERO INOX.  P/SOPAPA COCINA
# 239            9900.666  REJILLA ACERO INOX.  C/TORNILLO CROMADO P/SOPA...
#
#     empaque       precio                            producto
# 2        24  3867.054857  FLOTANTES ACCIONAMIENTO HORIZONTAL
# 3        12  4114.963256  FLOTANTES ACCIONAMIENTO HORIZONTAL
# 6        10  5972.612938   FLOTANTES ALTA PRESION - SIN BOYA
# 7        10  6485.983497   FLOTANTES ALTA PRESION - SIN BOYA
# 8        10  7370.008542   FLOTANTES ALTA PRESION - SIN BOYA
# ..      ...          ...                                 ...
# 235      20   189.138146              REPUESTOS PARA SOPAPAS
# 236      20   189.138146              REPUESTOS PARA SOPAPAS
# 237      20   373.301869              REPUESTOS PARA SOPAPAS
# 238      20   373.301869              REPUESTOS PARA SOPAPAS
# 239      20   373.301869              REPUESTOS PARA SOPAPAS
#
# [178 rows x 5 columns]

# %%
df
# Out:
#                  codigo                                        descripcion  \
# 2             13000.649                             FLOTANTE COMPLETO 1/2"
# 3             13000.650                             FLOTANTE COMPLETO 3/4"
# 6             13001.805                         FLOTANTE ALTA PRESION 1/2"
# 7             13001.806       FLOTANTE ALTA PRESION 1/2" VARILLA REGULABLE
# 8             13001.807                         FLOTANTE ALTA PRESION 3/4"
# ..                  ...                                                ...
# 235  9900.113                   TORNILLO P/SOPAPA LAVATORIO 3/16 x 3"
# 236            9900.661            TORNILLO P/SOPAPA COCINA 3/16 x 2"
# 237  9900.117                      REJILLA ACERO INOX.  P/SOPAPA LAVATORIO
# 238            9900.662               REJILLA ACERO INOX.  P/SOPAPA COCINA
# 239            9900.666  REJILLA ACERO INOX.  C/TORNILLO CROMADO P/SOPA...
#
#     empaque       precio                            producto
# 2        24  3867.054857  FLOTANTES ACCIONAMIENTO HORIZONTAL
# 3        12  4114.963256  FLOTANTES ACCIONAMIENTO HORIZONTAL
# 6        10  5972.612938   FLOTANTES ALTA PRESION - SIN BOYA
# 7        10  6485.983497   FLOTANTES ALTA PRESION - SIN BOYA
# 8        10  7370.008542   FLOTANTES ALTA PRESION - SIN BOYA
# ..      ...          ...                                 ...
# 235      20   189.138146              REPUESTOS PARA SOPAPAS
# 236      20   189.138146              REPUESTOS PARA SOPAPAS
# 237      20   373.301869              REPUESTOS PARA SOPAPAS
# 238      20   373.301869              REPUESTOS PARA SOPAPAS
# 239      20   373.301869              REPUESTOS PARA SOPAPAS
#
# [178 rows x 5 columns]

# %%
#ELIMINO LAS FILAS DONDE LA PRIMER COLUMNA CONTENGA VALORES NULOS YA QUE SE DEBEN A FUNCIONAR COMO SEAPRADORES ENTRE LAS TABLAS DE TIPO DE PRODUCTO
df = df.dropna(subset=[df.columns[0]])
df = df.dropna(subset=[df.columns[3]])
df
# Out:
#                  codigo                                        descripcion  \
# 2             13000.649                             FLOTANTE COMPLETO 1/2"
# 3             13000.650                             FLOTANTE COMPLETO 3/4"
# 6             13001.805                         FLOTANTE ALTA PRESION 1/2"
# 7             13001.806       FLOTANTE ALTA PRESION 1/2" VARILLA REGULABLE
# 8             13001.807                         FLOTANTE ALTA PRESION 3/4"
# ..                  ...                                                ...
# 235  9900.113                   TORNILLO P/SOPAPA LAVATORIO 3/16 x 3"
# 236            9900.661            TORNILLO P/SOPAPA COCINA 3/16 x 2"
# 237  9900.117                      REJILLA ACERO INOX.  P/SOPAPA LAVATORIO
# 238            9900.662               REJILLA ACERO INOX.  P/SOPAPA COCINA
# 239            9900.666  REJILLA ACERO INOX.  C/TORNILLO CROMADO P/SOPA...
#
#     empaque       precio                            producto
# 2        24  3867.054857  FLOTANTES ACCIONAMIENTO HORIZONTAL
# 3        12  4114.963256  FLOTANTES ACCIONAMIENTO HORIZONTAL
# 6        10  5972.612938   FLOTANTES ALTA PRESION - SIN BOYA
# 7        10  6485.983497   FLOTANTES ALTA PRESION - SIN BOYA
# 8        10  7370.008542   FLOTANTES ALTA PRESION - SIN BOYA
# ..      ...          ...                                 ...
# 235      20   189.138146              REPUESTOS PARA SOPAPAS
# 236      20   189.138146              REPUESTOS PARA SOPAPAS
# 237      20   373.301869              REPUESTOS PARA SOPAPAS
# 238      20   373.301869              REPUESTOS PARA SOPAPAS
# 239      20   373.301869              REPUESTOS PARA SOPAPAS
#
# [178 rows x 5 columns]

# %%
df.to_excel('./data/out/RAO.xlsx')
